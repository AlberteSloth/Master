# %%
#=using Pkg
Pkg.add("CSV")

Pkg.add("DataFrames")
=#

# %%
using CSV
using DataFrames

df = CSV.read("C:\\Users\\alber\\OneDrive - Danmarks Tekniske Universitet\\KBS\\Speciale\\Data\\Processed_Proteomics.csv", DataFrame)
# Out:
# 4220×66 DataFrame
#   Row │ Column1         ambiguous  sample_conc(fmol/µg)_WT A Pellet  invivo_co ⋯
#       │ String15        Bool?      Union{Missing, Float64}           Union{Mis ⋯
# ──────┼─────────────────────────────────────────────────────────────────────────
#     1 │ NP_001230905.1      false                          0.0                 ⋯
#     2 │ NP_001230906.1      false                          4.91663
#     3 │ NP_001230907.1      false                         58.7812
#     4 │ NP_001230910.1      false                          0.728509
#     5 │ NP_001230912.1      false                          1.62078             ⋯
#     6 │ NP_001230917.1      false                          0.199855
#     7 │ NP_001230921.1      false                          0.123757
#     8 │ NP_001230923.2      false                          0.362641
#   ⋮   │       ⋮             ⋮                     ⋮                            ⋱
# ...

# %%
summary(df)
#print(df)
# Out:
# "4220×66 DataFrame"

# %%
filter(:Column1 => ==("XP_035298021.1"), df)
# Out:
# 1×66 DataFrame
#  Row │ Column1         ambiguous  sample_conc(fmol/µg)_WT A Pellet  invivo_con ⋯
#      │ String15        Bool?      Union{Missing, Float64}           Union{Miss ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ XP_035298021.1      false                          0.636307             ⋯
#                                                               63 columns omitted

# %%
# PFKM isoform X1
PFKM = filter(:Column1 => ==("XP_027252233.1"), df)

#5'-AMP-activated protein kinase catalytic subunit alpha-1 isoform X2
AMPK_alpha = filter(:Column1 => ==("XP_027257169.1"),df) 

#5'-AMP-activated protein kinase subunit gamma-1 isoform X1 
AMPK_gamma = filter(:Column1 => ==("XP_027252295.1"),df)

#5'-AMP-activated protein kinase subunit beta-1 isoform X1
AMPK_beta = filter(:Column1 => ==("XP_027269995.1"),df) 

print(PFKM, AMPK_alpha)

# %%
# Invivo concentration WT A Pellet
Invivo_WT_A_PFKM = PFKM[1,4]

Invivo_WT_A_AMPK = AMPK_alpha[1,4]
# Out:
# 5.2501700644625364e-5

# %%
Invivo_AMPK = df[df.Column1 .==("XP_027257169.1"), Cols(startswith("invivo"))]

Invivo_PFKM = df[df.Column1 .==("XP_027252233.1"), Cols(startswith("invivo"))]

Invivo_PFKM_WTs = df[df.Column1 .==("XP_027252233.1"), Cols(c -> startswith(c, "invivo") && contains(c, "WT"))]
# Out:
# 1×4 DataFrame
#  Row │ invivo_conc(mM)_WT A Pellet  invivo_conc(mM)_WT B Pellet  invivo_conc(m ⋯
#      │ Union{Missing, Float64}      Union{Missing, Float64}      Union{Missing ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │                  3.60441e-5                    4.1474e-5                ⋯
#                                                                2 columns omitted

# %%
Invivo_PFKM = df[df.Column1 .==("XP_027252233.1"), Cols(c -> startswith(c, "invivo") && contains(c, "WT"))]
# Out:
# 1×4 DataFrame
#  Row │ invivo_conc(mM)_WT A Pellet  invivo_conc(mM)_WT B Pellet  invivo_conc(m ⋯
#      │ Union{Missing, Float64}      Union{Missing, Float64}      Union{Missing ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │                  3.60441e-5                    4.1474e-5                ⋯
#                                                                2 columns omitted

# %%
print(Invivo_AMPK, Invivo_PFKM)

Invivo_PFKM_WT = Invivo_PFKM[:, Cols(contains("WT"))]

# %%
Invivo_WT_AMPK_mean = (5.25+6.29+6.08+5.53)/4
Invivo_Zela_AMPK_mean = (6.53+6.27+6.78+7.73)/4
print(Invivo_WT_AMPK_mean," ", Invivo_Zela_AMPK_mean)
# Out:
# 5.7875 6.827500000000001

# %%
a = [4,6,8,10,12,14,16,18]
Invivo_AMPK =  AMPK_alpha[1,a]

Invivo_PFKM =  PFKM[1,a]
sum(PFKM[1,a])
# Out:
# 0.00041362939621712567

# %%
filter(:Column1 => ==("XP_027260924.1"), df)
# Out:
# 0×66 DataFrame
#  Row │ Column1   ambiguous  sample_conc(fmol/µg)_WT A Pellet  invivo_conc(mM)_ ⋯
#      │ String15  Bool?      Union{Missing, Float64}           Union{Missing, F ⋯
# ─────┴──────────────────────────────────────────────────────────────────────────
#                                                               63 columns omitted

# %%
# Loof for AMPK
# 5'-AMP-activated protein kinase subunit beta-2 isoform X2:
filter(:Column1 => ==("XP_027249549.1"),df)
# Out:
# 0×66 DataFrame
#  Row │ Column1   ambiguous  sample_conc(fmol/µg)_WT A Pellet  invivo_conc(mM)_ ⋯
#      │ String15  Bool?      Union{Missing, Float64}           Union{Missing, F ⋯
# ─────┴──────────────────────────────────────────────────────────────────────────
#                                                               63 columns omitted

# %%
# 5'-AMP-activated protein kinase subunit beta-2 isoform X2
filter(:Column1 => ==("XP_027249550.1"),df)
# Out:
# 0×66 DataFrame
#  Row │ Column1   ambiguous  sample_conc(fmol/µg)_WT A Pellet  invivo_conc(mM)_ ⋯
#      │ String15  Bool?      Union{Missing, Float64}           Union{Missing, F ⋯
# ─────┴──────────────────────────────────────────────────────────────────────────
#                                                               63 columns omitted

# %%
#5'-AMP-activated protein kinase subunit beta-2 isoform X3 
filter(:Column1 => ==("XP_027249551.1"),df)
# Out:
# 0×66 DataFrame
#  Row │ Column1   ambiguous  sample_conc(fmol/µg)_WT A Pellet  invivo_conc(mM)_ ⋯
#      │ String15  Bool?      Union{Missing, Float64}           Union{Missing, F ⋯
# ─────┴──────────────────────────────────────────────────────────────────────────
#                                                               63 columns omitted

# %%
# Out:
# 0×66 DataFrame
#  Row │ Column1   ambiguous  sample_conc(fmol/µg)_WT A Pellet  invivo_conc(mM)_ ⋯
#      │ String15  Bool?      Union{Missing, Float64}           Union{Missing, F ⋯
# ─────┴──────────────────────────────────────────────────────────────────────────
#                                                               63 columns omitted

# %%
#5'-AMP-activated protein kinase subunit gamma-1 isoform X3
filter(:Column1 => ==("XP_027252296.1"),df)
# Out:
# 0×66 DataFrame
#  Row │ Column1   ambiguous  sample_conc(fmol/µg)_WT A Pellet  invivo_conc(mM)_ ⋯
#      │ String15  Bool?      Union{Missing, Float64}           Union{Missing, F ⋯
# ─────┴──────────────────────────────────────────────────────────────────────────
#                                                               63 columns omitted

# %%
#5'-AMP-activated protein kinase subunit gamma-3 
filter(:Column1 => ==("XP_027253050.1"),df)
# Out:
# 0×66 DataFrame
#  Row │ Column1   ambiguous  sample_conc(fmol/µg)_WT A Pellet  invivo_conc(mM)_ ⋯
#      │ String15  Bool?      Union{Missing, Float64}           Union{Missing, F ⋯
# ─────┴──────────────────────────────────────────────────────────────────────────
#                                                               63 columns omitted

# %%
# Out:
# 1×66 DataFrame
#  Row │ Column1         ambiguous  sample_conc(fmol/µg)_WT A Pellet  invivo_con ⋯
#      │ String15        Bool?      Union{Missing, Float64}           Union{Miss ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ XP_027257169.1      false                          0.627284             ⋯
#                                                               63 columns omitted

# %%
#5'-AMP-activated protein kinase catalytic subunit alpha-1 isoform X1
filter(:Column1 => ==("XP_027257170.2"),df)
# Out:
# 0×66 DataFrame
#  Row │ Column1   ambiguous  sample_conc(fmol/µg)_WT A Pellet  invivo_conc(mM)_ ⋯
#      │ String15  Bool?      Union{Missing, Float64}           Union{Missing, F ⋯
# ─────┴──────────────────────────────────────────────────────────────────────────
#                                                               63 columns omitted

# %%
#5'-AMP-activated protein kinase catalytic subunit alpha-2 isoform X2
filter(:Column1 => ==("XP_027258139.1"),df)
# Out:
# 0×66 DataFrame
#  Row │ Column1   ambiguous  sample_conc(fmol/µg)_WT A Pellet  invivo_conc(mM)_ ⋯
#      │ String15  Bool?      Union{Missing, Float64}           Union{Missing, F ⋯
# ─────┴──────────────────────────────────────────────────────────────────────────
#                                                               63 columns omitted

# %%
# Out:
# 1×66 DataFrame
#  Row │ Column1         ambiguous  sample_conc(fmol/µg)_WT A Pellet  invivo_con ⋯
#      │ String15        Bool?      Union{Missing, Float64}           Union{Miss ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ XP_027269995.1      false                          0.149886             ⋯
#                                                               63 columns omitted

# %%
filter(:Column1 => ==("NP_001233655.1"),df)
# Out:
# 1×66 DataFrame
#  Row │ Column1         ambiguous  sample_conc(fmol/µg)_WT A Pellet  invivo_con ⋯
#      │ String15        Bool?      Union{Missing, Float64}           Union{Miss ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ NP_001233655.1      false                           17.6107             ⋯
#                                                               63 columns omitted

# %% [markdown]
# g6p
#                       mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  \
# cell_line[CHO-S wt] -7.762  0.314  -8.363   -7.176      0.006    0.004
# cell_line[CHO-ZeLa] -7.591  0.321  -8.213   -6.991      0.007    0.005
# ln_conc_sigma        0.611  0.187   0.327    0.947      0.005    0.003
#
#                      ess_bulk  ess_tail  r_hat
# cell_line[CHO-S wt]  2746.885  1951.486  1.001
# cell_line[CHO-ZeLa]  2491.630  1974.560  1.001
# ln_conc_sigma        1724.824  2029.566  1.001
#
#
# dhap
#                        mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  \
# cell_line[CHO-S wt] -13.059  0.165 -13.365  -12.736      0.003    0.002
# cell_line[CHO-ZeLa] -10.967  0.167 -11.281  -10.653      0.004    0.003
# ln_conc_sigma         0.315  0.103   0.155    0.499      0.002    0.002
#
#                      ess_bulk  ess_tail  r_hat
# cell_line[CHO-S wt]  2792.889  1959.402  1.002
# cell_line[CHO-ZeLa]  2447.975  1828.414  1.001
# ln_conc_sigma        1812.448  2149.411  1.001
#
#
# atp
#                       mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  \
# cell_line[CHO-S wt] -5.643  0.166  -5.956   -5.330      0.004    0.003
# cell_line[CHO-ZeLa] -5.679  0.163  -5.989   -5.379      0.003    0.002
# ln_conc_sigma        0.314  0.106   0.169    0.511      0.002    0.002
#
#                      ess_bulk  ess_tail  r_hat
# cell_line[CHO-S wt]  2178.338  1740.843  1.001
# cell_line[CHO-ZeLa]  2656.732  1923.132  1.002
# ln_conc_sigma        1907.449  2320.371  1.002
#
# adp
#                       mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  \
# cell_line[CHO-S wt] -6.616  0.169  -6.926   -6.300      0.003    0.002
# cell_line[CHO-ZeLa] -6.777  0.170  -7.120   -6.468      0.003    0.002
# ln_conc_sigma        0.322  0.108   0.174    0.511      0.003    0.002
#
#                      ess_bulk  ess_tail  r_hat
# cell_line[CHO-S wt]  2606.977  2040.564  1.001
# cell_line[CHO-ZeLa]  2909.635  1821.813  1.001
# ln_conc_sigma        1686.077  1939.749  1.001
#
# amp
#                        mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  \
# cell_line[CHO-S wt] -12.151  0.274 -12.668  -11.616      0.005    0.004
# cell_line[CHO-ZeLa] -11.124  0.267 -11.634  -10.619      0.005    0.004
# ln_conc_sigma         0.523  0.161   0.277    0.809      0.004    0.003
#
#                      ess_bulk  ess_tail  r_hat
# cell_line[CHO-S wt]  3119.148  2365.990  1.001
# cell_line[CHO-ZeLa]  3002.180  2221.257  1.001
# ln_conc_sigma        1880.507  2187.868  1.001
#
# cit
#                       mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  \
# cell_line[CHO-S wt] -3.930  0.225  -4.339   -3.491      0.004    0.003
# cell_line[CHO-ZeLa] -3.785  0.234  -4.215   -3.330      0.004    0.003
# ln_conc_sigma        0.440  0.141   0.238    0.691      0.003    0.002
#
#                      ess_bulk  ess_tail  r_hat
# cell_line[CHO-S wt]  2621.201  2155.329  1.002
# cell_line[CHO-ZeLa]  3167.886  1943.537  1.001
# ln_conc_sigma        1939.538  2319.205  1.001
#
# fdp
#                       mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  \
# cell_line[CHO-S wt] -8.215  0.824  -9.772   -6.618      0.018    0.012
# cell_line[CHO-ZeLa] -4.894  0.807  -6.395   -3.373      0.015    0.011
# ln_conc_sigma        1.575  0.475   0.859    2.418      0.012    0.009
#
#                      ess_bulk  ess_tail  r_hat
# cell_line[CHO-S wt]  2425.433  1635.263  1.001
# cell_line[CHO-ZeLa]  2898.978  2180.393  1.000
# ln_conc_sigma        1982.883  2074.829  1.001
#
# f6p
#                       mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  \
# cell_line[CHO-S wt] -7.776  0.301  -8.378   -7.241      0.006    0.004
# cell_line[CHO-ZeLa] -7.590  0.294  -8.153   -7.046      0.005    0.004
# ln_conc_sigma        0.579  0.179   0.297    0.886      0.004    0.003
#
#                      ess_bulk  ess_tail  r_hat
# cell_line[CHO-S wt]  2583.016  2239.062  1.001
# cell_line[CHO-ZeLa]  3218.981  2432.185  1.000
# ln_conc_sigma        2178.532  2478.133  1.000

# %%
#using ModelingToolkit, DifferentialEquations, Random, Distributions, Plots

exp(-8.378)

#r = rand(LogNormal(-7.776, 0.314),1)
# Out:
# 0.00022986922447232672

# %%
C_ATP = exp(1.257) #M to mM
C_ADP = exp(0.284) 
C_cit = exp(2.97)
C_AMP = exp(-5.251)
C_G6P = exp(-0.862)
C_GAP = exp(-8.159) # No data
C_DHAP = exp(-6.159)

C = [C_ATP C_ADP C_cit C_AMP C_G6P C_GAP C_DHAP]
# Out:
# 1×7 Matrix{Float64}:
#  3.51486  1.32843  19.4919  0.00524227  0.422317  0.000286148  0.00211437

# %%
C_ATP = exp(1) #M to mM
C_ADP = exp(1) 
C_cit = exp(1)
C_AMP = exp(-5)
C_G6P = exp(1)
C_GAP = exp(-5) # No data
C_DHAP = exp(-5)

C = [C_ATP C_ADP C_cit C_AMP C_G6P C_GAP C_DHAP]
# Out:
# 1×7 Matrix{Float64}:
#  2.71828  2.71828  2.71828  0.00673795  2.71828  0.00673795  0.00673795
